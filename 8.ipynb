# %%
#W8A1
class Cylinder:
    def __init__(self, radius, height):
        self.radius = radius
        self.height = height
        self.pi = 3.14
    def surface_area(self):
        return 2 * self.pi * self.radius**2 + 2 * self.pi * self.radius * self.height
    def volume(self):
        return self.pi * self.radius**2 * self.height
r, h = map(float, input().split())
cyl = Cylinder(r, h)
print(f"{cyl.surface_area():.2f} {cyl.volume():.2f}")
# Out:
# 3 4
# 131.88 113.04

# %%
#W8A2
class Date:
    def __init__(self, day, month, year):
        self.day = day
        self.month = month
        self.year = year

    def is_valid(self):
        days_in_month = [31, 28, 31, 30, 31, 30,
                         31, 31, 30, 31, 30, 31]

        if (self.year % 400 == 0) or (self.year % 4 == 0 and self.year % 100 != 0):
            days_in_month[1] = 29

        if self.month < 1 or self.month > 12:
            return False
        if self.day < 1 or self.day > days_in_month[self.month - 1]:
            return False
        return True

    def next_day(self):
        days_in_month = [31, 28, 31, 30, 31, 30,
                         31, 31, 30, 31, 30, 31]
        if (self.year % 400 == 0) or (self.year % 4 == 0 and self.year % 100 != 0):
            days_in_month[1] = 29

        d, m, y = self.day, self.month, self.year

        d += 1
        if d > days_in_month[m - 1]:
            d = 1
            m += 1
            if m > 12:
                m = 1
                y += 1
        return Date(d, m, y)

date_str = input().strip()
try:
    dd, mm, yyyy = map(int, date_str.split("/"))
    d = Date(dd, mm, yyyy)
    if not d.is_valid():
        print("INVALID")
    else:
        next_d = d.next_day()
        print(f"{next_d.day:02d}/{next_d.month:02d}/{next_d.year:04d}")
except:
    print("INVALID")
# Out:
# 31/12/2024
# 01/01/2025

# %%
#W8A3
class toa_do:
    def __init__(self, x, y):
        self.x = x
        self.y = y
    def xet(self):
        if self.x==0 and self.y==0:
            return "Gốc toạ độ"
        elif self.x==0 and self.y!=0:
            return "Trên trục Oy",self.x
        elif self.x!=0 and self.y==0:
            return "Tren truc Ox",self.y
        elif self.x!=0 and self.y!=0:
            return "khoảng cách: ",((self.x**2)+(self.y**2))**0.5
x, y = map(int, input().split())
a = toa_do(x, y)
print(a.xet())

# %%
#W8A4
class Calculator:
    def __init__(self, a, b):
        self.a = a
        self.b = b

    def set_numbers(self, a, b):
        self.a = a
        self.b = b

    def add(self):
        return self.a + self.b

    def subtract(self):
        return self.a - self.b

    def product(self):
        return self.a * self.b

    def divide(self):
        if self.b == 0:
            return "Error: Division by zero"
        return self.a / self.b

    def power(self):
        return self.a ** self.b

    def mod(self):
        if self.b == 0:
            return "Error: Modulo by zero"
        return self.a % self.b


# --- Chương trình chính ---
def main():
    a, b = map(float, input("Nhập 2 số ban đầu: ").split())
    calc = Calculator(a, b)

    while True:
        print("\n--- MENU ---")
        print("1. Cộng")
        print("2. Trừ")
        print("3. Nhân")
        print("4. Chia")
        print("5. Hàm mũ")
        print("6. Mod (phần dư)")
        print("7. Nhập lại 2 số mới")

        choice = input("Chọn phép toán (1-7): ")

        if choice == "1":
            print("Kết quả:", calc.add())
        elif choice == "2":
            print("Kết quả:", calc.subtract())
        elif choice == "3":
            print("Kết quả:", calc.product())
        elif choice == "4":
            print("Kết quả:", calc.divide())
        elif choice == "5":
            print("Kết quả:", calc.power())
        elif choice == "6":
            print("Kết quả:", calc.mod())
        elif choice == "7":
            a, b = map(float, input("Nhập 2 số mới: ").split())
            calc.set_numbers(a, b)
            print("Đã cập nhật 2 số mới.")
        else:
            print("Lựa chọn không hợp lệ!")

        exit_choice = input("Bạn có muốn thoát? (yes/YES/Yes để thoát): ")
        if exit_choice.lower() == "yes":
            print("Chương trình kết thúc.")
            break


if __name__ == "__main__":
    main()
# Out:
# Nhập 2 số ban đầu: 3 4
#
# --- MENU ---
# 1. Cộng
# 2. Trừ
# 3. Nhân
# 4. Chia
# 5. Hàm mũ
# 6. Mod (phần dư)
# 7. Nhập lại 2 số mới
# Chọn phép toán (1-7): 1
# Kết quả: 7.0
# Bạn có muốn thoát? (yes/YES/Yes để thoát): yes
# Chương trình kết thúc.

# %%
#W8A5
class Shoppingcart:
  def __init__ (self):
    self.sp=[]
  def them_sp(self,ten,gia):
    self.sp.append({"ten":ten,"gia":gia})
    print(f"đã thêm {ten} với giá {gia} vào giỏ hàng")
  def xoa_sp(self,ten):
    for sp in self.sp:
      if sp["ten"]==ten:
        self.sp.remove(sp)
        print(f"{ten} đã được xóa khỏi giỏ hàng")
  def kt_rong(self):
    if len(self.sp)==0:
      print("giỏ hàng hiện đang rỗng")
    else:
      print("giỏ hàng hiện không rỗng")
  def tien_tong(self):
    tong=0
    for sp in self.sp:
      tong+=sp["gia"]
    print(f"tổng tiền là {tong}")
  def hien_thi(self):
    print("danh sách sản phẩm trong giỏ hàng:")
    for sp in self.sp:
      print(f"{sp["ten"]} với giá {sp["gia"]}")
  def xoa(self):
    self.sp.clear()
    print("giỏ hàng đã được xóa")
  def chuong_trinh_chinh(self):
    Sh=Shoppingcart()
    while True:
      print("1.thêm sản phẩm")
      print("2.xóa sản phẩm")
      print("3.kiểm tra giỏ hàng rỗng")
      print("4.tính tiền tổng")
      print("5.hiển thị giỏ hàng")
      print("6.xóa giỏ hàng")
      n=int(input("chọn chức năng: "))
      if n==1:
        ten=input("nhập tên sản phẩm: ")
        gia=float(input("nhập giá sản phẩm: "))
        Sh.them_sp(ten,gia)
      elif n==2:
        ten=input("nhập tên sản phẩm:")
        Sh.xoa_sp(ten)
      elif n==3:
        Sh.kt_rong()
      elif n==4:
        Sh.tien_tong()
      elif n==5:
        Sh.hien_thi()
      elif n==6:
        Sh.xoa()
      thoat=(input("bạn có muốn thoát khong?"))
      if thoat.lower()=="có":
        break
if __name__=="__main__":
    Sh=Shoppingcart()
    Sh.chuong_trinh_chinh()
# Out:
# 1.thêm sản phẩm
# 2.xóa sản phẩm
# 3.kiểm tra giỏ hàng rỗng
# 4.tính tiền tổng
# 5.hiển thị giỏ hàng
# 6.xóa giỏ hàng
# chọn chức năng: 1
# nhập tên sản phẩm: 1
# nhập giá sản phẩm: 1
# đã thêm 1 với giá 1.0 vào giỏ hàng
# bạn có muốn thoát khong?có

# %%
#W8A6
class hcn:
  def __init__(self,w,h):
    self.w=w
    self.h=h
  def s(self):
    return self.w*self.h*k*k
  def p(self):
    return (self.w*k+self.h*k)*2
a,b,k=map(int,input().split())
h=hcn(a,b)
print(h.s())
print(h.p())
# Out:
# 2 5 2
# 40
# 28

# %%
#W8A7
import math

class Fraction:
    def __init__(self, num, den):
        if den == 0:
            raise ValueError("Mẫu số không được bằng 0")
        self.num = num
        self.den = den
        self.simplify()

    def simplify(self):
        # Rút gọn phân số
        g = math.gcd(self.num, self.den)
        self.num //= g
        self.den //= g
        # Quy ước mẫu số dương
        if self.den < 0:
            self.num = -self.num
            self.den = -self.den

    def add(self, other):
        return Fraction(self.num * other.den + other.num * self.den,
                        self.den * other.den)

    def sub(self, other):
        return Fraction(self.num * other.den - other.num * self.den,
                        self.den * other.den)

    def mul(self, other):
        return Fraction(self.num * other.num, self.den * other.den)

    def div(self, other):
        return Fraction(self.num * other.den, self.den * other.num)

    def __str__(self):
        return f"{self.num}/{self.den}"


# ------------------ MAIN ------------------
def main():
    # Input dạng: a b op c d
    a, b, op, c, d = input().split()
    a, b, c, d = int(a), int(b), int(c), int(d)

    f1 = Fraction(a, b)
    f2 = Fraction(c, d)

    if op == '+':
        result = f1.add(f2)
    elif op == '-':
        result = f1.sub(f2)
    elif op == '*':
        result = f1.mul(f2)
    elif op == '/':
        result = f1.div(f2)
    else:
        raise ValueError("Phép toán không hợp lệ")

    print(result)


if __name__ == "__main__":
    main()
# Out:
# 2 4 - 1 4
# 1/4

# %%
#W8A8
class bank:
  def __init__(self,owner,balance):
    self.owner=owner
    self.balance=int(balance)
  def lenh(self):
    n=int(input())
    for i in range(n):
      print('----MENU----')
      print('chọn 1: deposit tiền gửi')
      print('chọn 2: whitdrawn tiền rút')
      choice=int(input())
      if choice==1:
        pluss=int(input('nhập số tiền cần gửi: '))
        self.balance+=pluss
      if choice==2:
        minus=int(input('nhập số tiền cần rút: '))
        if self.balance>=minus:
          self.balance-=minus
        else:
          print('số dư không đủ')

    return print(f'Chủ tài khoản: {self.owner}, Số dư tài khoản: {self.balance}')

a ,b = map(str,input().split())
acount=bank(a,b)
acount.lenh()

# %%
#W8A9
class diem_trung_binh:
    def __init__(self,name):
        self.name=name
    def add_score(self,subject,score):
        avg=[]
        n=int(input())
        for i in range(n):
            subject=input("Nhap ten mon hoc: ")
            score=float(input("Nhap diem mon hoc: "))
            avg.append(score)
        return sum(avg)/len(avg)
    def xep_hang(self,avg):
        if avg>=8:
            return "Good"
        elif 6.5<=avg<8:
            return "Average"
        else:
            return "Poor"
a=input("Nhap ten sinh vien: ")
sv=diem_trung_binh(a)
average=sv.add_score("",0)
xep_loai=sv.xep_hang(average)
print("Diem trung binh cua",a,"la:",average,"xep loai:",xep_loai)

# %%
#W8A10
class Book:
    def __init__(self, title, author, year):
        self.title = title
        self.author = author
        self.year = year

class Library:
    def __init__(self):
        self.books = []

    def add(self, book):
        self.books.append(book)

    def count_by_author(self, name):
        return sum(1 for b in self.books if b.author == name)

    def find_by_year(self, y):
        return sum(1 for b in self.books if b.year == y)


# Xử lý input/output
def main():
    n = int(input().strip())
    library = Library()

    for _ in range(n):
        line = input().strip()
        if line.startswith("ADD"):
            # Ví dụ: ADD title; author,year
            _, rest = line.split(" ", 1)
            title_part, rest2 = rest.split(";")
            author_part, year_part = rest2.split(",")
            title = title_part.strip()
            author = author_part.strip()
            year = int(year_part.strip())
            library.add(Book(title, author, year))

        elif line.startswith("COUNTYEAR"):
            _, year_str = line.split(" ", 1)
            year = int(year_str.strip())
            print(library.find_by_year(year))

        elif line.startswith("COUNT"):
            _, author = line.split(" ", 1)
            print(library.count_by_author(author.strip()))


if __name__ == "__main__":
    main()

# %%
#W8A11
import math

def vector_sub(a, b):
    return [a[i] - b[i] for i in range(3)]

def cross(u, v):
    return [u[1]*v[2] - u[2]*v[1],
            u[2]*v[0] - u[0]*v[2],
            u[0]*v[1] - u[1]*v[0]]

def dot(u, v):
    return sum(u[i]*v[i] for i in range(3))

def norm(u):
    return math.sqrt(dot(u, u))

# Input
A = list(map(float, input().split()))
B = list(map(float, input().split()))
C = list(map(float, input().split()))
D = list(map(float, input().split()))

# Pháp tuyến mặt phẳng (A,B,C)
AB = vector_sub(B, A)
AC = vector_sub(C, A)
n1 = cross(AB, AC)

# Pháp tuyến mặt phẳng (B,C,D)
BC = vector_sub(C, B)
BD = vector_sub(D, B)
n2 = cross(BC, BD)

# Góc giữa hai mặt phẳng
cos_phi = dot(n1, n2) / (norm(n1) * norm(n2))
# tránh sai số vượt [-1,1]
cos_phi = max(-1, min(1, cos_phi))
phi = math.degrees(math.acos(cos_phi))

print(f"{phi:.2f}")

# %%
#W8A12
class ComplexNumber:
    def __init__(self, initRealPart, initImaginaryPart):
        self.realPart = initRealPart
        self.imaginaryPart = initImaginaryPart

    def multiply(self, other):
        real = self.realPart * other.realPart - self.imaginaryPart * other.imaginaryPart
        imag = self.realPart * other.imaginaryPart + self.imaginaryPart * other.realPart
        return ComplexNumber(real, imag)


def main():
    # Nhập số phức thứ nhất
    r1, i1 = map(float, input().split())
    c1 = ComplexNumber(r1, i1)

    # Nhập số phức thứ hai
    r2, i2 = map(float, input().split())
    c2 = ComplexNumber(r2, i2)

    # Nhân và in kết quả
    result = c1.multiply(c2)
    print(f"{int(result.realPart)} {int(result.imaginaryPart)}")


if __name__ == "__main__":
    main()

# %%
#W8A13
import math

class Triangle:
    def __init__(self, initEdge1, initEdge2, initEdge3):
        self.a = initEdge1
        self.b = initEdge2
        self.c = initEdge3

    def getArea(self):
        # Kiểm tra điều kiện tam giác
        if (self.a + self.b <= self.c or
            self.a + self.c <= self.b or
            self.b + self.c <= self.a or
            self.a <= 0 or self.b <= 0 or self.c <= 0):
            return -1  # không hợp lệ

        # Công thức Heron
        p = (self.a + self.b + self.c) / 2
        area = math.sqrt(p * (p - self.a) * (p - self.b) * (p - self.c))
        return area


def main():
    # Nhập 3 cạnh
    edges = list(map(int, input().split()))
    t = Triangle(edges[0], edges[1], edges[2])
    area = t.getArea()

    if area == -11:
        print("invalid")
    else:
        print(f"{area:.2f}")


if __name__ == "__main__":
    main()
